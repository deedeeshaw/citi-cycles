# %%
import pandas as pd

# %%
autos_df = pd.read_csv("autos_dd.csv", encoding='Latin-1', low_memory=False)

# %%
autos_df.head()
# Out:
#        dateCrawled                            name  seller offerType    price  \
# 0  3/24/2016 11:52                      Golf_3_1.6  privat   Angebot    480.0
# 1  3/24/2016 10:58            A5_Sportback_2.7_Tdi  privat   Angebot  18300.0
# 2  3/14/2016 12:52  Jeep_Grand_Cherokee_"Overland"  privat   Angebot   9800.0
# 3  3/17/2016 16:54              GOLF_4_1_4__3TRER  privat   Angebot   1500.0
# 4  3/31/2016 17:25  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot   3600.0
#
#   abtest vehicleType  yearOfRegistration    gearbox  powerPS  model kilometer  \
# 0   test         NaN              1993.0    manuell      0.0   golf    150000
# 1   test       coupe              2011.0    manuell    190.0    NaN    125000
# 2   test         suv              2004.0  automatik    163.0  grand    125000
# 3   test  kleinwagen              2001.0    manuell     75.0   golf    150000
# 4   test  kleinwagen              2008.0    manuell     69.0  fabia     90000
#
# ...

# %%
autos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371540 entries, 0 to 371539
# Data columns (total 20 columns):
# dateCrawled            371539 non-null object
# name                   371539 non-null object
# seller                 371538 non-null object
# offerType              371538 non-null object
# price                  371538 non-null float64
# abtest                 371538 non-null object
# vehicleType            333669 non-null object
# yearOfRegistration     371537 non-null float64
# gearbox                351329 non-null object
# powerPS                371538 non-null float64
# model                  351054 non-null object
# kilometer              371538 non-null object
# monthOfRegistration    371537 non-null float64
# fuelType               338151 non-null object
# brand                  371537 non-null object
# notRepairedDamage      299477 non-null object
# dateCreated            371537 non-null object
# nrOfPictures           371537 non-null float64
# ...

# %%
autos_df.head()
# Out:
#        dateCrawled                            name  seller offerType    price  \
# 0  3/24/2016 11:52                      Golf_3_1.6  privat   Angebot    480.0
# 1  3/24/2016 10:58            A5_Sportback_2.7_Tdi  privat   Angebot  18300.0
# 2  3/14/2016 12:52  Jeep_Grand_Cherokee_"Overland"  privat   Angebot   9800.0
# 3  3/17/2016 16:54              GOLF_4_1_4__3TRER  privat   Angebot   1500.0
# 4  3/31/2016 17:25  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot   3600.0
#
#   abtest vehicleType  yearOfRegistration    gearbox  powerPS  model kilometer  \
# 0   test         NaN              1993.0    manuell      0.0   golf    150000
# 1   test       coupe              2011.0    manuell    190.0    NaN    125000
# 2   test         suv              2004.0  automatik    163.0  grand    125000
# 3   test  kleinwagen              2001.0    manuell     75.0   golf    150000
# 4   test  kleinwagen              2008.0    manuell     69.0  fabia     90000
#
# ...

# %%
# autos_df.rename(columns={'yearOfRegistration': 'Registration Year'})
autos = autos_df.groupby('offerType')
autos.head()
# Out:
#             dateCrawled                                               name  \
# 0       3/24/2016 11:52                                         Golf_3_1.6
# 1       3/24/2016 10:58                               A5_Sportback_2.7_Tdi
# 2       3/14/2016 12:52                     Jeep_Grand_Cherokee_"Overland"
# 3       3/17/2016 16:54                                 GOLF_4_1_4__3TRER
# 4       3/31/2016 17:25                     Skoda_Fabia_1.4_TDI_PD_Classic
# 16744    4/3/2016 15:48                               Suche_VW_T5_Multivan
# 90921   3/27/2016 14:55  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60
# 142235  3/27/2016 22:51  "SUCHE_OPEL_VECTRA_B."SUCHE",privat,Angebot,0,...
# 142236              NaN                                                NaN
# 142237              ell                                                 90
# 144166  3/14/2016 18:51  [SUCHE]_BMW_e46_Coupe_330ci_M_Paket_Facelift__...
# ...

# %%
autos

# %%
autos["Registration Year"].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-49230c78854e> in <module>()
# ----> 1 autos["Registration Year"].astype('int')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ...
